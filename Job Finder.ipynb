# %% [markdown]
# # Job Finder Jypiter Notebook app
#
# Jonathan Mehmannavaz
# mehmannavazjonathan@gmail.com
#
# Last edit 12/31/2025

# %% [markdown]
# # Platform used
#
# Linkedlin (in dev)
#
# Indeed (in dev)
#
# Glassdoor (in dev)
#
# ZipRecruiter (in dev)

# %% [markdown]
# # Indeed
